# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.use('qt4agg')
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif'
#解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False

# 环境可能需要
# %matplotlib inline

# 开启画布
plt.figure()

# 描点
plt.plot([1,0,9],[4,5,6])

# 展示
plt.show()

# %% [markdown]
# ## 容器层
# * 画板层
# - 画布层
# - 绘图区/坐标系
#     1. x,y轴张成区域
#     - 辅助显示层
#     - 图像层

# %% [markdown]
# ### 折线图绘制与显示

# %%
# 展现上海一周的天气，比如从星期一到星期日的天气温度如下
# plt.figure(figsize=(20,8),dpi=80)
# figsize：指定图的长度
# dpi：图像的清晰度
# 返回一个fig对象
# plt.savefig(path)
# 1、创建画布
# plt.figure()
plt.figure(figsize=(20,8),dpi=80)

# 2、绘制图像
plt.plot([1,2,3,4,5,6,7],[17,17,18,15,11,11,13])

# 保存图像(不可在show后面调用这个函数)
plt.savefig("test.png")

# 3、显示图像
plt.show()

# %% [markdown]
# ### 完善原始折线图（辅助显示层）

# %%
# 需求：画出城市11点到12点1小时内每分钟的温度变化折线图，温度范围在15度~18度
import random
# 1、准备数据x，y
x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]

# 2、创建画布
plt.figure(figsize=(20, 8),dpi=80)

# 3、创建图像
plt.plot(x,y_shanghai)

# 修改x，y刻度
# 准备x的刻度说明
x_labels = ["11点{}分".format(i) for i in x]
# print(x_labels)
# print(help(plt.xticks()))
plt.xticks(x[::5],x_labels[::5])
plt.yticks(range(0,40,5))

# 添加网格显示
plt.grid(True, linestyle="--", alpha=0.5)

# 添加标题
plt.xlabel("时间变化")
plt.ylabel("温度变化")
plt.title("中午11点0分到12点之间的温度变化图示")

# 4、显示图像
plt.show()

# %% [markdown]
# ### 完善原始折线图2(图像层)

# %%
# 需求: 再添加一个城市的温度变化
# 收集到北京当天的温度变化情况,温度在1到3度之间

# 1、准备数据x，y
x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]
y_beijing = [random.uniform(1,3) for i in x]

# 2、创建画布
plt.figure(figsize=(20, 8),dpi=80)

# 3、创建图像
plt.plot(x,y_shanghai,color="r",linestyle="--",label="上海")
plt.plot(x,y_beijing,color="b",linestyle="-",label="北京")

# 显示图例
# 0-7
# plt.legend(loc=3)  
plt.legend()

# 修改x，y刻度
# 准备x的刻度说明
x_labels = ["11点{}分".format(i) for i in x]
# print(x_labels)
# print(help(plt.xticks()))
plt.xticks(x[::5],x_labels[::5])
plt.yticks(range(0,40,5))

# 添加网格显示
plt.grid(True, linestyle="--", alpha=0.5)

# 添加标题
plt.xlabel("时间变化")
plt.ylabel("温度变化")
plt.title("上海,北京中午11点0分到12点之间的温度变化图示")

# 4、显示图像
plt.show()

# %% [markdown]
# ### 多个坐标系显示-plt.subplots(面向对象的图画方法)

# %%
# 需求: 再添加一个城市的温度变化
# 收集到北京当天的温度变化情况,温度在1到3度之间

# 1、准备数据x，y
x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]
y_beijing = [random.uniform(1,3) for i in x]

# 2、创建画布
# plt.figure(figsize=(20, 8),dpi=80)
figure,axes = plt.subplots(nrows=1,ncols=2,figsize=(20,8),dpi=80)

# 3、创建图像
axes[0].plot(x,y_shanghai,color="r",linestyle="--",label="上海")
axes[1].plot(x,y_beijing,color="b",linestyle="-",label="北京")

# 显示图例
# 0-7
# plt.legend(loc=3)  
axes[0].legend()
axes[1].legend()

# 修改x，y刻度
# 准备x的刻度说明
x_labels = ["11点{}分".format(i) for i in x]
# print(x_labels)
# print(help(plt.xticks()))
axes[0].set_xticks(x[::5],x_labels[::5])
axes[0].set_yticks(range(0,40,5))
axes[1].set_xticks(x[::5],x_labels[::5])
axes[1].set_yticks(range(0,40,5))

# 添加网格显示
axes[0].grid(True, linestyle="--", alpha=0.5)
axes[1].grid(True, linestyle="--", alpha=0.5)

# 添加标题
axes[0].set_xlabel("时间变化")
axes[0].set_ylabel("温度变化")
axes[0].set_title("上海中午11点0分到12点之间的温度变化图示")
axes[1].set_xlabel("时间变化")
axes[1].set_ylabel("温度变化")
axes[1].set_title("北京中午11点0分到12点之间的温度变化图示")

# 4、显示图像
plt.show()

# %% [markdown]
# ### 绘制数学函数图像

# %%
import numpy as np
# 1,准备x,y数据
x = np.linspace(-1,1,1000)
y = 2*x*x

# 2,创建画布
plt.figure(figsize=(20,8),dpi=80)

# 3,绘制图像
plt.plot(x,y)

# 4,显示网格
plt.grid(linestyle="--",alpha=0.5)

# 5,显示图像
plt.show()

# %% [markdown]
# ### 散点图

# %%
# 数据准备
x = [225.98,247.07,253.14,457.85,241.58,301.01,20.67,288.64,
    163.56,120.06,207.83,342.75,147.9,53.06,224.72,29.51,
    21.61,483.21,245.25,399.25,343.35]

y = [196.63,203.88,210.75,372.74,202.41,247.61,24.9,239.34,
    140.32,104.15,176.84,288.23,128.79,49.64,191.74,33.1,
    30.74,400.02,205.35,330.64,283.45]

# 创建画布
plt.figure(figsize=(20,8),dpi=80)

# 绘制画像
plt.scatter(x,y)

# 显示图像
plt.show()
# Out:
# 21
# 21

# %% [markdown]
# ### 柱状图

# %%
# 1,数据准备
x = ['雷神3','诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴','降魔传','追捕']
y = [73853,57767,22354,15969,14839,8725,8716,8318]

# 2,创建画布
plt.figure(figsize=(20,8),dpi=80)

# 3,绘制柱状图
x_ticks = range(len(x))
plt.bar(x,y,color=['b','r','g','y','c','m','k','b'])

# 4,修改刻度
# plt.xticks(x_ticks,x)

# 4,显示网格
plt.grid(linestyle="--",alpha=0.5)

plt.title("电影售票")

# 5,显示
plt.show()

# %%
# 准备数据
movie_name=['雷神3:诸神黄昏','正义联盟','寻梦环游记']

first_day = [10587.6,10062,1275.7]
first_weekend = [36224.9,34479.6,11830]

plt.figure(figsize=(20,8),dpi=80)

plt.bar(range(3),first_day,width=0.2)
plt.bar([0.2,1.2,2.2],first_weekend,width=0.2)

plt.xticks([0.1,1.1,2.1],movie_name)

plt.show()

# %% [markdown]
# ### 绘制直方图

# %%
time = [131,98,125,131,124,139,131,117,128,108,135,138,131,102,107,114,119]
plt.figure(figsize=(20,8),dpi=80)
distance = 2
group_num = int((max(time)-min(time))/distance)
plt.hist(time,bins = group_num,density=True)  # density 频率  否则  次数
plt.xticks(range(min(time),max(time)+2,distance))
plt.grid(linestyle="--",alpha=0.5)
plt.show()

# %% [markdown]
# ### 饼图绘制

# %%
# 1,数据准备
movie_name = ['雷神3','诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴','降魔传','追捕']
place_count = [73853,57767,22354,15969,14839,8725,8716,8318]

# 2,创建画布
plt.figure(figsize=(20,8),dpi=80)

# 3,绘制柱状图
plt.pie(place_count,labels=movie_name,colors=['b','r','g','y','c','m','k','b'],autopct="%1.2f%%")

# 4,修改刻度
# plt.xticks(x_ticks,x)

plt.axis("equal")
plt.legend()

# 4,显示网格
plt.grid(linestyle="--",alpha=0.5)

plt.title("电影售票")

# 5,显示
plt.show()
