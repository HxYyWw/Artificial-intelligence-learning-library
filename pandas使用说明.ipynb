# %%
import pandas
catalogue_info = pandas.read_csv("datas/tj.csv") # 以逗号为分隔符就可以使用read_csv
print(type(catalogue_info))
print(catalogue_info.dtypes)
# dtypes类型object，int，float，datetime，bool
print(help(pandas.read_csv))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 序号                 int64
# 单位                object
# 成果名称              object
# 技术水平              object
# 负责人               object
# 所属技术领域            object
# 合作单位              object
# 项目总规模或评估价值（万元）    object
# 目前所处阶段            object
# 知识产权情况            object
# 项目简介              object
# dtype: object
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
# 默认五行
# catalogue_info.head(3)

# 遍历后面几行
# catalogue_info.tail(4)

# 查看列属性
# catalogue_info.columns

# 查看表中的结构
# catalogue_info.shape

# 查看指定行的数据信息
# catalogue_info.loc[1]

# 返回四到七个样本
# catalogue_info.loc[3:6]
catalogue_info.loc[-1:]

# 获取指定列的所有数据
# tial = catalogue_info["单位"]
# tial = catalogue_info[["单位","成果名称"]]
# print(tial)

# 获取指定位置的数据
tail_detail = catalogue_info.loc[83,"单位"]
print(tail_detail)

# 筛选所需要的列信息
col_names = catalogue_info.columns.tolist()
print(col_names)
gram_columns = []

for c in col_names:
    if c.endswith("单位"):
        gram_columns.append(c)
gram_df = catalogue_info[gram_columns]
print(gram_df)
# Out:
# 铁道第三勘察设计院集团有限公司
# ['序号', '单位', '成果名称', '技术水平', '负责人', '所属技术领域', '合作单位', '项目总规模或评估价值（万元）', '目前所处阶段', '知识产权情况', '项目简介']
#                          单位                                               合作单位
# 0             天津市大力神非开挖工程公司                                                NaN
# 1                 天津市东丽区农林局                                                NaN
# 2     中国人民解放军军事医学科学院卫生装备研究所                                                NaN
# 3                  天津大学化工学院                                          天津海豚碳黑公司,
# 4              天津市液化气有限责任公司                                        天津市农村能源办公室,
# ...                     ...                                                ...
# 3815      中科院苏州纳米技术与纳米仿生研究所                                                NaN
# 3816    中国科学院苏州纳米技术与纳米仿生研究所  周扬所属技术领域先进制造与自动化技术水平国内领先目前所处阶段初期阶段项目总规模或评估价值（万...
# 3817               中科院力学研究所                                                NaN
# ...

# %%
# 根据values值进行排序
# catalogue_info.sort_values("序号",inplace = True)  # 默认升序  可以通过ascending指定降序  inplace = True  是否修改原本的矩阵
# print(catalogue_info["序号"])
new_catalogue_info = catalogue_info.sort_values("序号",inplace = False,ascending = False)
print(new_catalogue_info["序号"])
# 重新设置索引值
catalogue_info_reindexed = new_catalogue_info.reset_index(drop=True)
print(catalogue_info_reindexed["序号"][0:10])
# Out:
# 3819    21835
# 3818    21834
# 3817    21833
# 3816    21831
# 3815    21827
#         ...
# 4          23
# 3          14
# 2           8
# 1           6
# 0           5
# Name: 序号, Length: 3820, dtype: int64
# 0    21835
# 1    21834
# 2    21833
# 3    21831
# 4    21827
# 5    21826
# 6    21823
# 7    21820
# 8    21814
# 9    21795
# Name: 序号, dtype: int64

# %%
import numpy as np
import pandas as pd
# 获取数据
jingjinji_info = pd.read_csv("datas/jjj.csv")
# 获取列
address = jingjinji_info["联系单位地址"]
# print(address)
# 查看是否存在空值
address_is_null = pd.isnull(address)
# 查看空值
# print(address[address_is_null])
print(jingjinji_info["联系单位地址"][address_is_null])
# 查看不为空的值
print(jingjinji_info["联系单位地址"][address_is_null == False])
# Out:
# 25     NaN
# 36     NaN
# 42     NaN
# 84     NaN
# 103    NaN
# 104    NaN
# 128    NaN
# 130    NaN
# 131    NaN
# 147    NaN
# 148    NaN
# Name: 联系单位地址, dtype: object
# 0      河北省沧州市临港经济技术开发区规划一号路南
# 1              北京市朝阳区尚家楼甲48号
# 2          北京市东城区崇内大街后沟胡同17号
# 3           北京市西城区德胜门外安康胡同5号
# 4          北京市西城区复兴门外南礼士路17号
#                ...
# 149             天津市河东区六纬路93号
# 150               天津市南开区芥园西道
# 151               天津市南开区芥园西道
# 152             天津市南开区科研东路1号
# 153             天津市南开区科研东路1号
# Name: 联系单位地址, Length: 143, dtype: object

# %%
values = catalogue_info["项目总规模或评估价值（万元）"]

# 数据类型转换
# pd.to_numeric(values) # or pd.to_numeric(values, errors='raise') 若需要转换的值中无脏数据
# pd.to_numeric(values, errors='coerce') # 无效值强制转换为NaN
# pd.to_numeric(values, errors='ignore') # 如果遇到无效值，第三个选项就是忽略该操作：
catalogue_info["项目总规模或评估价值（万元）"] = pd.to_numeric(catalogue_info["项目总规模或评估价值（万元）"], errors='coerce')

# 计算平均值
# print(values)
# print(values[pd.isnull(values)])
values_is_null = pd.isnull(values)
good_values = catalogue_info["项目总规模或评估价值（万元）"][values_is_null == False]
print(good_values)
correct_mean_value = sum(good_values) / len(good_values)
print(correct_mean_value)

correct_mean_value = catalogue_info["项目总规模或评估价值（万元）"].mean()
print(correct_mean_value)
# values.astype(float)
# print(help(values.astype()))

# 去掉NaT的数据
print(help(catalogue_info.dropna))
# Out:
# 1        381.0
# 2         70.0
# 3          8.0
# 4         20.0
# 5         72.0
#          ...
# 3787       9.0
# 3789       9.0
# 3790      10.0
# 3792       9.0
# 3794    6799.0
# Name: 项目总规模或评估价值（万元）, Length: 3266, dtype: float64
# 2766.1297979179417
# 2766.1297979179417
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. versionchanged:: 1.0.0
#
# ...

# %%
a = [['a', '1.2', '4.2'], ['b', '70', '0.03'], ['x', '5', '0']]
df = pd.DataFrame(a)
df.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# dtype: object

# %%
# 统计关系
# 几等舱乘客的平均获救几率
passenger_survival = titanic_suervial.pivot_table(index="Pclass",values="Survived",aggfunc = np.mean)  # aggfunc = np.mean均值，index目标，values值
# 几等舱乘客的平均年龄
passenger_age = titanic_suervial.pivot_table(index="Pclass",values="Age") # 默认 aggfunc = np.mean
# 三个出发地点的总票和登船人数
port_stats = titanic_suervial.pivot_table(index="Embarked",values=["Fare","Survived"],aggfunc = np.sum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-19c9f520e87a> in <module>
#       1 # 统计关系
#       2 # 几等舱乘客的平均获救几率
# ----> 3 passenger_survival = titanic_suervial.pivot_table(index="Pclass",values="Survived",aggfunc = np.mean)  # aggfunc = np.mean均值，index目标，values值
#       4 # 几等舱乘客的平均年龄
#       5 passenger_age = titanic_suervial.pivot_table(index="Pclass",values="Age") # 默认 aggfunc = np.mean
#
# NameError: name 'titanic_suervial' is not defined

# %%
# 函数使用
def not_null_count(column):
    column_null = pd.isnull(column)
#     column_null = !column_null
    not_null = column[column_null==False]
    return len(not_null)

def is_null_count(column):
    column_null = pd.isnull(column)
#     column_null = !column_null
    not_null = column[column_null]
    return len(not_null)

column_not_null = jingjinji_info.apply(is_null_count)
print(column_not_null)


def which_class(row):
    pclass = row["Pclass"]
    if pd.isnull(pclass):
        return "Unkown"
    elif pclass == 1:
        return "First Class"
    elif pclass == 2:
        return "Second Class"
    elif pclass == 3:
        return "Third Class"
classes = titanic_suervial.apply(which_class, axis=1)
# Out:
# ID          0
# 成果名称        0
# 项目年度编号      0
# 省市          0
# 中图分类号       0
# 成果类别        0
# 成果分布年份      0
# 关键词         0
# 成果简介        0
# 鉴定部门      145
# 登记号        57
# 完成单位        0
# 完成人        22
# 应用行业名称      0
# 应用行业代码      0
# 联系单位地址     11
# 传真        126
# 电子邮件      137
# dtype: int64

# %%
a = [['a', '1.2', '4.2'], ['b', '70', '0.03'], ['x', '5', '0'],['c', '5', '0']]
df = pd.DataFrame(a)
df
# Out:
#    0    1     2
# 0  a  1.2   4.2
# 1  b   70  0.03
# 2  x    5     0
# 3  c    5     0
